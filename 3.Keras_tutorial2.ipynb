# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
 
model = Sequential()
model.add(Dense(512, activation='relu', input_dim=784))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
 
import numpy as np
data = np.random.random((1000, 784)) 
labels = np.random.randint(10, size=(1000, 10))

model.fit(data, labels, epochs=10, batch_size=32)
 
score=model.evaluate(data, labels)
print(score[1])
# Out:
# Epoch 1/10
# 32/32 [==============================] - 2s 12ms/step - loss: 491.6254 - accuracy: 0.1010
# Epoch 2/10
# 32/32 [==============================] - 0s 11ms/step - loss: 1468.7028 - accuracy: 0.1000
# Epoch 3/10
# 32/32 [==============================] - 0s 11ms/step - loss: 2511.3118 - accuracy: 0.0990
# Epoch 4/10
# 32/32 [==============================] - 0s 13ms/step - loss: 3823.6064 - accuracy: 0.1100
# Epoch 5/10
# 32/32 [==============================] - 1s 23ms/step - loss: 5015.8799 - accuracy: 0.1060
# Epoch 6/10
# 32/32 [==============================] - 1s 29ms/step - loss: 6303.1685 - accuracy: 0.1070
# Epoch 7/10
# 32/32 [==============================] - 1s 25ms/step - loss: 8048.4043 - accuracy: 0.1060
# Epoch 8/10
# 32/32 [==============================] - 1s 23ms/step - loss: 8983.4512 - accuracy: 0.1000
# Epoch 9/10
# 32/32 [==============================] - 1s 17ms/step - loss: 9740.0059 - accuracy: 0.1200
# Epoch 10/10
# 32/32 [==============================] - 0s 11ms/step - loss: 11075.2793 - accuracy: 0.1040
# 32/32 [==============================] - 1s 7ms/step - loss: 10213.0605 - accuracy: 0.1050
# 0.10499999672174454
